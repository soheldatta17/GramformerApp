# %% [markdown]
# <a href="https://colab.research.google.com/github/soheldatta17/GramformerApp/blob/main/Gramformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Happytransformer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 38.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.6/303.6 kB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.9 MB/s eta 0:00:00
# ...

# %%
import torch

# Assuming you have your model
model = happy_tt.model

# Save the model state dictionary
torch.save(model.state_dict(), "t5_base_grammar_correction.pth")

# %%
import torch
from happytransformer import HappyTextToText, TTSettings

# Reinitialize the HappyTextToText object
happy_tt = HappyTextToText("T5", "t5-base")

# Load the saved state dictionary
happy_tt.model.load_state_dict(torch.load("t5_base_grammar_correction.pth"))

# Set the model to evaluation mode
happy_tt.model.eval()

# Define the settings
args = TTSettings(num_beams=5, min_length=1)

# Use the model for inference
result = happy_tt.generate_text("grammar: This sentences has has bads grammar.", args=args)
print(result.text)  # This sentence has bad grammar.
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# This sentence has bad grammar.
